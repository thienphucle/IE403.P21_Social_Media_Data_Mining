# %%
import pandas as pd

# %%
df1 = pd.read_csv('tiktok_feed_1.csv')
df2 = pd.read_csv('tiktok_feed_2.csv')
df3 = pd.read_csv('tiktok_feed_3.csv')
df4 = pd.read_csv('tiktok_feed_4.csv')
df5 = pd.read_csv('tiktok_feed_5.csv')
df6 = pd.read_csv('tiktok_feed_6.csv')
combine = pd.concat([df1, df2, df3, df4, df5, df6])
combine
# Out:
#                  user_name user_followers               vid_id  \
# 0             abahoatattoo          71.8K  7502050641603284245
# 1            tuankiet.2000           9.7M  7501653242284166408
# 2        beatvn_viralworld           4.7M  7501665798855904520
# 3          kinggroup_drama          23.3K  7501641851787611399
# 4              anh.be.vui3         402.4K  7502432620886625556
# ...                    ...            ...                  ...
# 1286  blogtamsu.nghenghiep         784.5K  7498267240031161607
# 1287             zhicuan12          64.8K  7484837106481646853
# 1288                vfuho_         922.5K  7473942044973534486
# 1289                   NaN            NaN  7502832980969229575
# 1290          thecarest456          63.1K  7502832980969229575
#
#                                             vid_caption         vid_postTime  \
# 0          Khách xăm Triệu Vân mà sao tô đen thui z Thỏ  2025-05-08 12:27:59
# ...

# %%
combine['vid_id'].nunique()
# Out:
# 4175

# %%
final = combine.drop_duplicates(subset=['vid_id'])
final
# Out:
#                  user_name user_followers               vid_id  \
# 0             abahoatattoo          71.8K  7502050641603284245
# 1            tuankiet.2000           9.7M  7501653242284166408
# 2        beatvn_viralworld           4.7M  7501665798855904520
# 3          kinggroup_drama          23.3K  7501641851787611399
# 4              anh.be.vui3         402.4K  7502432620886625556
# ...                    ...            ...                  ...
# 1285             chang.mie           2.7M  7504220925139717394
# 1286  blogtamsu.nghenghiep         784.5K  7498267240031161607
# 1287             zhicuan12          64.8K  7484837106481646853
# 1288                vfuho_         922.5K  7473942044973534486
# 1289                   NaN            NaN  7502832980969229575
#
#                                             vid_caption         vid_postTime  \
# 0          Khách xăm Triệu Vân mà sao tô đen thui z Thỏ  2025-05-08 12:27:59
# ...

# %%
final['user_name'].isnull().sum()
# Out:
# 48

# %%
final = final.dropna(subset=['user_name'])
final
# Out:
#                  user_name user_followers               vid_id  \
# 0             abahoatattoo          71.8K  7502050641603284245
# 1            tuankiet.2000           9.7M  7501653242284166408
# 2        beatvn_viralworld           4.7M  7501665798855904520
# 3          kinggroup_drama          23.3K  7501641851787611399
# 4              anh.be.vui3         402.4K  7502432620886625556
# ...                    ...            ...                  ...
# 1284           lethuha9898           6007  7504590659081309448
# 1285             chang.mie           2.7M  7504220925139717394
# 1286  blogtamsu.nghenghiep         784.5K  7498267240031161607
# 1287             zhicuan12          64.8K  7484837106481646853
# 1288                vfuho_         922.5K  7473942044973534486
#
#                                             vid_caption         vid_postTime  \
# 0          Khách xăm Triệu Vân mà sao tô đen thui z Thỏ  2025-05-08 12:27:59
# ...

# %%
final.to_csv('tiktok_feed.csv', index=False)
