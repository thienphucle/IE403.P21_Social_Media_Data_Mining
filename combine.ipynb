# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # combine data

# %%
hn4 = pd.read_csv('tiktok_feed.csv')
hn5 = pd.read_csv('tiktok_feed_combined.csv')
hn = pd.concat([hn4, hn5], ignore_index=True)
hn = hn[hn['vid_nview'].notna()]
hn = hn.drop_duplicates(subset=['vid_id'], keep='last')
hn = hn[hn['user_name'].notna()]
hn.reset_index(drop=True, inplace=True)
hn
# Out:
#            user_name user_followers               vid_id  \
# 0      lenguyentravi         304.9K  7506832682593094928
# 1        ongsaucocay          17.4K  7507991840340135186
# 2        _iamhung081         125.1K  7492318870162787591
# 3      ngcc.linhh894           1991  7497123500767857938
# 4           m.giy.xn          95.1K  7483367904189091080
# ...              ...            ...                  ...
# 10097       cht.si.c           4302  7498928267718774024
# 10098       duckoi2k           4.2M  7492002243726626056
# 10099   linnstore_68         149.4K  7496112418347732231
# 10100     xuan_nam93          13.2K  7501258770366958856
# 10101     rhyder.dgh           1.7M  7491653129147092231
#
#                                              vid_caption         vid_postTime  \
# 0                                  Giấc mơ của chung 🤷🏻🦢  2025-05-21 09:44:45
# 1                     Đơn giản dễ làm lắm đó quý vị ơi..  2025-05-24 12:42:52
# ...

# %%
hn.to_csv('tiktok_feed_combined.csv', index=False)

# %% [markdown]
# # Extract most viral video

# %%
data = pd.read_csv('finalProject\data\preprocessed_data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_35532\1902939844.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data = pd.read_csv('finalProject\data\preprocessed_data.csv')

# %%
top_videos = data.loc[data.groupby("user_name")["viral_score"].idxmax()]
top_videos = top_videos.sort_values(by="viral_score", ascending=False)
top_videos.to_csv("top_video_per_user.csv", index=False)
top_videos
# Out:
#               user_name  user_nfollower               vid_id  \
# 5825           zinh9889         74200.0  7504695782835113224
# 8413            00.25.d        170000.0  7484985666850278663
# 9580            .ryosae         14500.0  7505403512763763986
# 5926    lavieenrose2107         65900.0  7497908077081955605
# 7121  laumientayhuedong         74800.0  7473672384667553042
# ...                 ...             ...                  ...
# 2437        buingocni86         47000.0  7499247222903672095
# 1616         26m1.20898          1658.0  7489081098656402693
# 5876      ducphuocsshop          7209.0  7497845633894583559
# 7385            zaldz31           342.0  7488885300878396690
# 7917         m.ry.du.da         13100.0  7499328608528256274
#
#                                             vid_caption  \
# 5825                                                NaN
# 8413                                          fine shyt
# 9580                         anime wow yolo house 🥹❤️‍🔥
# ...

# %%
top_videos = pd.read_csv("raw_2.csv")

split_dfs = np.array_split(top_videos, 4)

for i, df_part in enumerate(split_dfs):
    df_part.to_csv(f"raw_2{i+1}.csv", index=False)
# Out:
# c:\Users\Lenovo\miniconda3\envs\ds_env\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
top_videos = pd.read_csv("top_videos_part_1.csv")

split_dfs = np.array_split(top_videos, 4)

for i, df_part in enumerate(split_dfs):
    df_part.to_csv(f"part_{i+1}.csv", index=False)
# Out:
# c:\Users\Lenovo\miniconda3\envs\ds_env\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
p1 = pd.read_csv('users_p1.csv')
p2 = pd.read_csv('users_p2.csv')
tp = pd.concat([p1, p2], ignore_index=True)
tp = tp[tp['vid_nview'].notna()]
tp = tp[tp['vid_duration'].notna()]
tp = tp.drop_duplicates(subset=['vid_id'], keep='last')
tp = tp[tp['user_name'].notna()]
tp.reset_index(drop=True, inplace=True)
tp
# Out:
#       user_name user_nfollower               vid_id  \
# 0     chi.nese_         353.1K  7474564827701087504
# 1     chi.nese_         353.1K  7474939314661592336
# 2     chi.nese_         353.1K  7474986391370255632
# 3     chi.nese_         353.1K  7475211113097956624
# 4     chi.nese_         353.1K  7475599950194150674
# ...         ...            ...                  ...
# 1957   food9946          46.6K  7506503047816727816
# 1958   food9946          46.6K  7506149624353148167
# 1959   food9946          46.6K  7506100257407732999
# 1960   food9946          46.6K  7505808334478478610
# 1961   food9946          46.6K  7505754071890922760
#
#                                vid_caption         vid_postTime  \
# 0                          原版没学会，来整个不一样的吧～  2025-02-23 10:48:59
# 1                                 我们这松弛感够么  2025-02-24 11:02:11
# 2                                 谁懂最后的含金量  2025-02-24 14:04:52
# 3                           《李羲承进行曲》慢速分解教学  2025-02-25 04:36:54
# ...

# %%
tp.to_csv('tiktok_users.csv', index=False)

# %%
users = pd.read_csv('users_videos.csv')
users = users[users['vid_nview'].notna()]
users['user_name'].nunique()
users.to_csv('users_videos_data.csv', index=False)

# %%
users = pd.read_csv('users_videos_data.csv')
data = pd.read_csv('finalProject\data\preprocessed_top_viral.csv')
filtered_data = data[data['user_name'].isin(users['user_name'].unique())]
filtered_data.to_csv('filtered_top_viral.csv', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8524\2537672523.py:2: SyntaxWarning: invalid escape sequence '\d'
#   data = pd.read_csv('finalProject\data\preprocessed_top_viral.csv')
