# %%
import pandas as pd

# %%
df1 = pd.read_csv('1_500.csv')
df2 = pd.read_csv('3_1000.csv')
df3 = pd.read_csv('4_1000.csv')
df4 = pd.read_csv('5_500.csv')
#df5 = pd.read_csv('tiktok_feed_5.csv')
#df6 = pd.read_csv('tiktok_feed_6.csv')
combine = pd.concat([df1, df2, df3, df4])
combine
# Out:
#               user_name user_followers               vid_id  \
# 0    hoaminzy_hoadambut           6.5M  7477145543064521992
# 1              benam410          33.5K  7479452835134868757
# 2           tinathaothi           4.5M  7498382042556566791
# 3            m.ry.du.da            13K  7499328608528256274
# 4             kyduyn997           1.1M  7480780797914483969
# ..                  ...            ...                  ...
# 495         leelee.0402          66.7K  7477922310289313042
# 496         preemnichaa         107.5K  7492452042384968978
# 497     ngothithanhdtvn          72.6K  7492636150675393809
# 498   h.vi.i.chp.nh.k.y          22.1K  7492051677869083912
# 499             duyee02            712  7500484464657583367
#
#                                            vid_caption         vid_postTime  \
# 0                        Bắc Ninh vốn trọng chữ tình 🥰  2025-03-02 09:43:29
# 1    Ăn sáng 1 phần còn cất dành tiền mua Nguyên li...  2025-03-08 14:56:57
# ...

# %%
combine['vid_id'].nunique()
# Out:
# 2358

# %%
final = combine.drop_duplicates(subset=['vid_id'])
final
# Out:
#               user_name user_followers               vid_id  \
# 0    hoaminzy_hoadambut           6.5M  7477145543064521992
# 1              benam410          33.5K  7479452835134868757
# 2           tinathaothi           4.5M  7498382042556566791
# 3            m.ry.du.da            13K  7499328608528256274
# 4             kyduyn997           1.1M  7480780797914483969
# ..                  ...            ...                  ...
# 492     chaumoe.dreamer         241.9K  7476720615374736648
# 493        chuyennhadau         343.4K  7477586671555464456
# 497     ngothithanhdtvn          72.6K  7492636150675393809
# 498   h.vi.i.chp.nh.k.y          22.1K  7492051677869083912
# 499             duyee02            712  7500484464657583367
#
#                                            vid_caption         vid_postTime  \
# 0                        Bắc Ninh vốn trọng chữ tình 🥰  2025-03-02 09:43:29
# 1    Ăn sáng 1 phần còn cất dành tiền mua Nguyên li...  2025-03-08 14:56:57
# ...

# %%
final['user_name'].isnull().sum()
# Out:
# 42

# %%
final = final.dropna(subset=['user_name'])
final
# Out:
#               user_name user_followers               vid_id  \
# 0    hoaminzy_hoadambut           6.5M  7477145543064521992
# 1              benam410          33.5K  7479452835134868757
# 2           tinathaothi           4.5M  7498382042556566791
# 3            m.ry.du.da            13K  7499328608528256274
# 4             kyduyn997           1.1M  7480780797914483969
# ..                  ...            ...                  ...
# 492     chaumoe.dreamer         241.9K  7476720615374736648
# 493        chuyennhadau         343.4K  7477586671555464456
# 497     ngothithanhdtvn          72.6K  7492636150675393809
# 498   h.vi.i.chp.nh.k.y          22.1K  7492051677869083912
# 499             duyee02            712  7500484464657583367
#
#                                            vid_caption         vid_postTime  \
# 0                        Bắc Ninh vốn trọng chữ tình 🥰  2025-03-02 09:43:29
# 1    Ăn sáng 1 phần còn cất dành tiền mua Nguyên li...  2025-03-08 14:56:57
# ...

# %%
final['music_id'].isnull().sum()
final = final.dropna(subset=['music_id'])
final
# Out:
#              user_name user_followers               vid_id  \
# 1             benam410          33.5K  7479452835134868757
# 2          tinathaothi           4.5M  7498382042556566791
# 3           m.ry.du.da            13K  7499328608528256274
# 8           tttk888.vn         305.2K  7478343506247814408
# 9             vuvatram          20.9K  7499126978633534728
# ..                 ...            ...                  ...
# 490      kenhkhuyenmai         741.5K  7504662935000681736
# 493       chuyennhadau         343.4K  7477586671555464456
# 497    ngothithanhdtvn          72.6K  7492636150675393809
# 498  h.vi.i.chp.nh.k.y          22.1K  7492051677869083912
# 499            duyee02            712  7500484464657583367
#
#                                            vid_caption         vid_postTime  \
# 1    Ăn sáng 1 phần còn cất dành tiền mua Nguyên li...  2025-03-08 14:56:57
# 2      quá đẹp quá đỗi tự hào Việt Nam mình ơiiii 🇻🇳❤️  2025-04-28 15:11:57
# ...

# %%
final.to_csv('tiktok_feed_tp.csv', index=False)
